# %% [markdown]
# # Identifying High Risk Areas from NYC Traffic Conditions
#
# <hr/>
#
# *Data Cleaning -*

# %%
# libraries

# pliers
import pandas as pd
import numpy as np
import missingno as msno

# GIS 
import geopandas as gpd
from shapely.geometry import Point, Polygon

# viz
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Ingestion

# %%
df = pd.read_csv('../data/crash_features_2019.csv')
print(df.shape)
df.head()
# Out:
# (193813, 30)
#          DATE  CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 0  2019-01-01  01/01/2019       4:10  MANHATTAN   10075.0  40.774967
# 1  2019-01-01  01/01/2019      14:36  MANHATTAN   10002.0  40.720360
# 2  2019-01-01  01/01/2019       1:41        NaN       NaN  40.661663
# 3  2019-01-01  01/01/2019       6:30   BROOKLYN   11219.0  40.635017
# 4  2019-01-01  01/01/2019       7:03        NaN       NaN  40.868458
#
#    LONGITUDE                 LOCATION                    ON STREET NAME  \
# 0 -73.956800    (40.774967, -73.9568)  3 AVENUE
# 1 -73.988205   (40.72036, -73.988205)                               NaN
# 2 -73.923615  (40.661663, -73.923615)  WINTHROP STREET
# 3 -74.002680   (40.635017, -74.00268)  56 STREET
# 4 -73.821400    (40.868458, -73.8214)  HUTCHINSON RIVER PARKWAY
#
#        CROSS STREET NAME  ... CONTRIBUTING FACTOR VEHICLE 2  \
# 0         EAST 80 STREET  ...                   Unspecified
# 1                    NaN  ...                           NaN
# 2                    NaN  ...                   Unspecified
# 3  FORT HAMILTON PARKWAY  ...                   Unspecified
# 4                    NaN  ...                   Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4060620
# 1                            NaN       4060593
# 2                            NaN       4060491
# 3                            NaN       4061126
# 4                            NaN       4060550
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0                                Sedan  Station Wagon/Sport Utility Vehicle
# 1                                Sedan                                  NaN
# 2  Station Wagon/Sport Utility Vehicle                                Sedan
# 3  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
# 4                                 Taxi  Station Wagon/Sport Utility Vehicle
#
#    VEHICLE TYPE CODE 3  VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2                  NaN                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Create Day of Week Column
# <hr/>

# %%
# Checking date type

type(df['DATE'][1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# creates datatime for date column

df['DATE'] = pd.to_datetime(df['DATE'])

# %%
# creates a columns 

df['dayofweek'] =  df['DATE'].dt.dayofweek

# %%
# convert dayofweek to char 

df['dayofweek'] = df['dayofweek'].map ({0:'Mon',1:'Tues',2:'Wed',3:'Thurs',4:'Fri', 5:'Sat',6:'Sun' })

# %%
df.iloc[:,-1]
# Out:
# 0         Tues
# 1         Tues
# 2         Tues
# 3         Tues
# 4         Tues
#           ...
# 193808    Tues
# 193809    Tues
# 193810    Tues
# 193811    Tues
# 193812    Tues
# Name: dayofweek, Length: 193813, dtype: object

# %% [markdown]
# # Highways / Expressways / Parkways
# <hr/>
#
# Locating the highways, and creating a boolian column .

# %%
# randomly looking through street names to discover highway names

df.iloc[:,8:11].sample(10)
# Out:
#                           ON STREET NAME CROSS STREET NAME  \
# 173532  17 AVENUE                                      NaN
# 65228   36 AVENUE                                      NaN
# 175933                               NaN               NaN
# 91067   EAST 43 STREET                      CLARENDON ROAD
# 57489                                NaN               NaN
# 54675   21 STREET                                40 AVENUE
# 72152                                NaN               NaN
# 88263   FDR DRIVE                                      NaN
# 147129                               NaN               NaN
# 89181   PROSPECT EXPRESSWAY EAST                       NaN
#
#                                  OFF STREET NAME
# 173532                                       NaN
# 65228                                        NaN
# 175933  146       SOUTH AVENUE
# 91067                                        NaN
# 57489   1560      METROPOLITAN AVENUE
# 54675                                        NaN
# 72152   308       ROGERS AVENUE
# 88263                                        NaN
# 147129  308       EAST 73 STREET
# 89181                                        NaN

# %%
# mask for highways 

highways = "EXPRESSWAY|PKWY|PARKWAY|EXPY|FDR|BQE|EXPWY|HIGHWAY|HENRY HUDSON"

# %%
# number of rows where the crash was located on the a 'highway '

df[df['ON STREET NAME'].str.contains(highways, na =False)]['ON STREET NAME'].count()
# Out:
# 23869

# %%
# a list of the the unique highway names 

np.unique(df[df['ON STREET NAME'].str.contains(highways, na =False)]['ON STREET NAME'])
# Out:
# array(['BAY PARKWAY                     ',
#        'BAY RIDGE PARKWAY               ',
#        'BELT PARKWAY                    ',
#        'BRONX RIVER PARKWAY             ',
#        'BROOKLYN QNS EXPRESSWAY         ',
#        'BROOKLYN QUEENS EXPRESSWAY      ',
#        'BROOKLYN QUEENS EXPRESSWAY E/B  ',
#        'BROOKLYN QUEENS EXPRESSWAY RAMP ',
#        'BRUCKNER EXPRESSWAY             ',
#        'BRUCKNER EXPRESSWAY RAMP        ',
#        'CATHEDRAL PARKWAY               ',
#        'CHAPIN PARKWAY                  ',
#        'CLAREMONT PARKWAY               ',
#        'CLEARVIEW EXPRESSWAY            ',
#        'CROSS BRONX EXPRESSWAY          ',
#        'CROSS BRONX EXPY                ',
#        'CROSS BRONX EXPY RAMP           ',
#        'CROSS ISLAND PARKWAY            ',
#        'CROTONA PARKWAY                 ',
#        'DOUGLASTON PARKWAY              ',
#        'EAST MOSHOLU PARKWAY NORTH      ',
#        'EAST MOSHOLU PARKWAY SOUTH      ',
#        'EASTERN PARKWAY                 ',
#        'ELLINGTON PARKWAY               ',
#        'FDR DRIVE                       ',
#        'FDR DRIVE RAMP                  ',
#        'FOREST PARKWAY                  ',
#        'FORT HAMILTON PARKWAY           ',
#        'GOWANUS EXPRESSWAY              ',
#        'GOWANUS EXPY (BQE)              ',
#        'GRAND CENTRAL PARKWAY           ',
#        'GRAND CENTRAL PKWY              ',
#        'GRANT HIGHWAY                   ',
#        'HENRY HUDSON PARKWAY            ',
#        'HENRY HUDSON PARKWAY RAMP       ',
#        'HORACE HARDING EXPRESSWAY       ',
#        'HORATIO PARKWAY                 ',
#        'HUDSON PARKWAY                  ',
#        'HUTCHINSON RIVER PARKWAY        ',
#        'HUTCHINSON RIVER PARKWAY EAST   ',
#        'JACKIE ROBINSON PKWY            ',
#        'KINGS HIGHWAY                   ',
#        'KINGS HIGHWAY SOUTH             ',
#        'KOREAN WAR VETS PARKWAY         ',
#        'KOREAN WAR VETS PARKWAY RAMP    ',
#        'LAURELTON PARKWAY               ',
#        'LITTLE NECK PARKWAY             ',
#        'LONG ISLAND EXPRESSWAY          ',
#        'MAJOR DEEGAN EXPRESSWAY         ',
#        'MAJOR DEEGAN EXPRESSWAY RAMP    ',
#        'MANHATTAN COLLEGE PARKWAY       ',
#        'MARATHON PARKWAY                ',
#        'MARINE PARKWAY                  ',
#        'MIDLAND PARKWAY                 ',
#        'MOSHOLU PARKWAY                 ',
#        'MOSHOLU PARKWAY EXTENSION       ',
#        'MOUNT EDEN PARKWAY              ',
#        'NASSAU EXPRESSWAY               ',
#        'OCEAN PARKWAY                   ',
#        'PARKWAY COURT                   ',
#        'PELHAM PARKWAY                  ',
#        'PELHAM PARKWAY NORTH            ',
#        'PELHAM PARKWAY SOUTH            ',
#        'PROSPECT EXPRESSWAY             ',
#        'PROSPECT EXPRESSWAY EAST        ',
#        'PROSPECT EXPRESSWAY RAMP        ',
#        'ROCKAWAY PARKWAY                ',
#        'SHERIDAN EXPRESSWAY             ',
#        'SHORE FRONT PARKWAY             ',
#        'SHORE PARKWAY                   ',
#        'SOUTHERN PARKWAY                ',
#        'STATEN ISLAND EXPRESSWAY        ',
#        'STATEN ISLAND EXPRESSWAY RAMP   ',
#        'SUNRISE HIGHWAY                 ',
#        'THROGS NECK EXPRESSWAY          ',
#        'THROGS NECK EXPY                ',
#        'UTOPIA PARKWAY                  ',
#        'VAN WYCK EXPWY                  ',
#        'VANWYCK EXPRESSWAY              ',
#        'WEST MOSHOLU PARKWAY NORTH      ',
#        'WEST MOSHOLU PARKWAY SOUTH      ',
#        'WEST SHORE EXPRESSWAY           ',
#        'WEST SIDE HIGHWAY               ',
#        'WHITESTONE EXPRESSWAY           '], dtype=object)

# %% [markdown]
# #### Create a Boolian Column, True crash was on a highway

# %%
#create a Boolian Column, True crash was on a highway 

df['highway'] =  df['ON STREET NAME'].str.contains(highways, na =False)
df['highway'].sample

# %%
# Out:
# <bound method NDFrame.sample of 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 193808    False
# 193809    False
# 193810     True
# 193811    False
# 193812    False
# Name: highway, Length: 193813, dtype: bool>

# %% [markdown]
# # a look

# %%
df.head()
# Out:
#         DATE  CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 0 2019-01-01  01/01/2019       4:10  MANHATTAN   10075.0  40.774967
# 1 2019-01-01  01/01/2019      14:36  MANHATTAN   10002.0  40.720360
# 2 2019-01-01  01/01/2019       1:41        NaN       NaN  40.661663
# 3 2019-01-01  01/01/2019       6:30   BROOKLYN   11219.0  40.635017
# 4 2019-01-01  01/01/2019       7:03        NaN       NaN  40.868458
#
#    LONGITUDE                 LOCATION                    ON STREET NAME  \
# 0 -73.956800    (40.774967, -73.9568)  3 AVENUE
# 1 -73.988205   (40.72036, -73.988205)                               NaN
# 2 -73.923615  (40.661663, -73.923615)  WINTHROP STREET
# 3 -74.002680   (40.635017, -74.00268)  56 STREET
# 4 -73.821400    (40.868458, -73.8214)  HUTCHINSON RIVER PARKWAY
#
#        CROSS STREET NAME  ... CONTRIBUTING FACTOR VEHICLE 4  \
# 0         EAST 80 STREET  ...                           NaN
# 1                    NaN  ...                           NaN
# 2                    NaN  ...                           NaN
# 3  FORT HAMILTON PARKWAY  ...                           NaN
# 4                    NaN  ...                           NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4060620
# 1                            NaN       4060593
# 2                            NaN       4060491
# 3                            NaN       4061126
# 4                            NaN       4060550
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0                                Sedan  Station Wagon/Sport Utility Vehicle
# 1                                Sedan                                  NaN
# 2  Station Wagon/Sport Utility Vehicle                                Sedan
# 3  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
# 4                                 Taxi  Station Wagon/Sport Utility Vehicle
#
#    VEHICLE TYPE CODE 3  VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5  dayofweek  \
# 0                  NaN                  NaN                  NaN       Tues
# 1                  NaN                  NaN                  NaN       Tues
# 2                  NaN                  NaN                  NaN       Tues
# 3                  NaN                  NaN                  NaN       Tues
# 4                  NaN                  NaN                  NaN       Tues
#
#   highway
# 0   False
# 1   False
# 2   False
# 3   False
# 4    True
#
# [5 rows x 32 columns]

# %%
# convert to np.... 
    
    # check which rows are missing zip code and borough 
    if (pd.isnull(row['ZIP CODE']) or pd.isnull(row['BOROUGH'])):# and (row['LOCATION']):
        
        # create Point for geo-positioning 
        geo_point = Point(row['LONGITUDE'],row['LATITUDE'])

        # itterates through and pulls zipcode polys to check 
        for ii, zipcode in zipcodes.iterrows():
            
            # checks polys and updates df rows
            if zipcode['geometry'].contains(geo_point):
                row['ZIP CODE'] = zipcode['postalCode']
                row['BOROUGH'] = zipcode['borough']
                df.at[i,'ZIP CODE'] = zipcode['postalCode']
                df.at[i,'BOROUGH'] = zipcode['borough'].upper()
                c += 1
                break

print(f'Number of rows updated {c}')
